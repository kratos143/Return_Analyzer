# %%
import pandas as pd
import numpy as np
import yfinance as yf
import sys
import os
from return_analyzer import ReturnAnalyzer

# %%
# Configuration
benchmark_symbol = "^NSEI"
risk_free_rate = 0.03

# Generate sample portfolio returns
dates = pd.date_range(start="2020-01-01", end="2024-12-31", freq='D')
portfolio_returns = pd.Series(np.random.normal(0.001, 0.01, len(dates)), index=dates)

# Fetch benchmark data
benchmark_data = yf.download(benchmark_symbol, start="2019-01-01", end="2024-12-31")
benchmark_returns = benchmark_data['Adj Close'].pct_change().dropna()



# Initialize analyzer
analyzer = ReturnAnalyzer(
    returns=portfolio_returns,
    benchmark=benchmark_returns,
    risk_free_rate=risk_free_rate
)

# Generate full report
analyzer.generate_full_report()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Performance Metrics:
#                                    Value
# Total Return (%)              135.069351
# CAGR (%)                       18.656095
# Annual Volatility (%)          15.728219
# Sharpe Ratio                    0.998855
# Sortino Ratio                   1.047079
# Max Drawdown (%)              -22.396147
# Max Drawdown Duration (Days)  205.000000
# Skewness                        0.123255
# Excess Kurtosis                -0.200632
# Value at Risk (95%) (%)         1.525022
# Conditional VaR (95%) (%)       1.824115
# Win Rate (%)                   52.427184
# Calmar Ratio                    0.833005
# Omega Ratio                     1.169072
# Ulcer Index                     0.065883
# Profit Factor                   1.203984
# Kelly Criterion (%)             8.882450
# Tail Ratio                      1.083543
# Gain to Pain Ratio              0.300939
# Jarque-Bera Statistic           5.202532
# JB p-value                      0.074180
# Ljung-Box p-value (lag=5)       0.837445
# Alpha                           0.154314
# Beta                            0.022412
# Information Ratio               0.133938
# Tracking Error (%)             24.421021
# Up Capture Ratio (%)           12.537123
# Down Capture Ratio (%)         -5.990636
# Active Share (%)               17.769696
# c:\Users\Kishan\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Kishan\Desktop\bt\Return_Analyzer\return_analyzer\return_analyzer.py:370: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_returns = self.returns.resample('M').apply(lambda x: (1 + x).prod() - 1)
