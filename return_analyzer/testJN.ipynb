# %%
import pandas as pd
import numpy as np
import yfinance as yf
import sys
import os
import os

from return_analyzer import ReturnAnalyzer

# %%
import pandas as pd
import numpy as np
import yfinance as yf

# Configuration
benchmark_symbol = "^NSEI"
risk_free_rate = 0.03

# Generate sample portfolio returns
dates = pd.date_range(start="2020-01-01", end="2022-12-31", freq='D')
portfolio_returns = pd.Series(np.random.normal(0.0005, 0.01, len(dates)), index=dates)

# Fetch benchmark data
benchmark_data = yf.download(benchmark_symbol, start="2020-01-01", end="2022-12-31")
benchmark_returns = benchmark_data['Adj Close'].pct_change().dropna()

# Align dates
portfolio_returns, benchmark_returns = portfolio_returns.align(benchmark_returns, join='inner')

# Initialize analyzer
analyzer = ReturnAnalyzer(
    returns=portfolio_returns,
    benchmark=benchmark_returns,
    risk_free_rate=risk_free_rate
)

# Generate full report
analyzer.generate_full_report()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Performance Metrics:
#                                    Value
# Total Return (%)               46.200653
# CAGR (%)                       13.532824
# Annual Volatility (%)          15.909387
# Sharpe Ratio                    0.701360
# Sortino Ratio                   0.702859
# Max Drawdown (%)              -16.883401
# Max Drawdown Duration (Days)  273.000000
# Skewness                       -0.052082
# Excess Kurtosis                -0.143416
# Value at Risk (95%) (%)         1.623785
# Conditional VaR (95%) (%)       2.021638
# Win Rate (%)                   53.020134
# Calmar Ratio                    0.801546
# Omega Ratio                     1.116551
# Ulcer Index                     0.073449
# Profit Factor                   1.149605
# Kelly Criterion (%)             6.899819
# Tail Ratio                      1.006648
# Gain to Pain Ratio              0.165646
# Jarque-Bera Statistic           0.975280
# JB p-value                      0.614074
# Ljung-Box p-value (lag=5)       0.898269
# Alpha                           0.107230
# Beta                            0.033398
# Information Ratio              -0.069321
# Tracking Error (%)             26.996104
# Up Capture Ratio (%)           11.643507
# Down Capture Ratio (%)          0.462765
# Active Share (%)               19.467629
# c:\Users\Kishan\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
