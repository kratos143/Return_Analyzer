# %%
import pandas as pd
import numpy as np
import yfinance as yf
import sys
import os

from return_analyzer import ReturnAnalyzer

# %%
benchmark_symbol = "^NSEI"

# Example returns data (replace with actual data)
dates = pd.date_range(start="2020-01-01", end="2022-12-31", freq='D')
portfolio_returns = pd.Series(np.random.randn(len(dates)) / 100, index=dates)

# Fetch historical data for the benchmark (NIFTY 50)
benchmark_data = yf.download(benchmark_symbol, start="2020-01-01", end="2022-12-31")
benchmark_returns = benchmark_data['Adj Close'].pct_change().dropna()

# Align the portfolio returns with the benchmark returns
portfolio_returns, benchmark_returns = portfolio_returns.align(benchmark_returns, join='inner')

# Initialize the ReturnAnalyzer with the portfolio returns and benchmark returns
analyzer = ReturnAnalyzer(portfolio_returns, benchmark_returns)


# Plot the monthly returns heatmap
#analyzer.plot_monthly_returns_heatmap()

#generate full report
analyzer.generate_full_report()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Performance Metrics:
# ===================
#                             Value
# Total Return            -7.055985
# CAGR                    -2.415579
# Annual Volatility       15.827909
# Sharpe Ratio            -0.077317
# Sortino Ratio           -0.077097
# Max Drawdown           -24.578800
# Max Drawdown Duration  430.000000
# Skewness                -0.010552
# Kurtosis                -0.275861
# Value at Risk (95%)      1.654517
# Conditional VaR (95%)    2.011503
# Win Rate                49.664430
# Alpha                   -0.000048
# Beta                    -0.000402
# Information Ratio       -0.623980
# Tracking Error           0.275801
# c:\Users\Kishan\Desktop\bt\Return_Analyzer\return_analyzer\return_analyzer.py:192: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_returns = self.returns.resample('M').agg(lambda x: (1 + x).prod() - 1)
