# %%
import pandas as pd
import numpy as np
import yfinance as yf
import sys
import os
import os

from return_analyzer import ReturnAnalyzer

# %%
import pandas as pd
import numpy as np
import yfinance as yf

# Configuration
benchmark_symbol = "^NSEI"
risk_free_rate = 0.03

# Generate sample portfolio returns
dates = pd.date_range(start="2020-01-01", end="2022-12-31", freq='D')
portfolio_returns = pd.Series(np.random.normal(0.0005, 0.01, len(dates)), index=dates)

# Fetch benchmark data
benchmark_data = yf.download(benchmark_symbol, start="2019-01-01", end="2022-12-31")
benchmark_returns = benchmark_data['Adj Close'].pct_change().dropna()

# Align dates
portfolio_returns, benchmark_returns = portfolio_returns.align(benchmark_returns, join='inner')

# Initialize analyzer
analyzer = ReturnAnalyzer(
    returns=portfolio_returns,
    benchmark=benchmark_returns,
    risk_free_rate=risk_free_rate
)

# Generate full report
analyzer.generate_full_report()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Performance Metrics:
#                                    Value
# Total Return (%)               -5.029911
# CAGR (%)                       -1.708266
# Annual Volatility (%)          16.422414
# Sharpe Ratio                   -0.204070
# Sortino Ratio                  -0.196726
# Max Drawdown (%)              -27.078049
# Max Drawdown Duration (Days)  463.000000
# Skewness                       -0.123098
# Excess Kurtosis                -0.090484
# Value at Risk (95%) (%)         1.753437
# Conditional VaR (95%) (%)       2.168731
# Win Rate (%)                   51.742627
# Calmar Ratio                   -0.063087
# Omega Ratio                     0.968272
# Ulcer Index                     0.136089
# Profit Factor                   0.996206
# Kelly Criterion (%)            -0.197061
# Tail Ratio                      0.940133
# Gain to Pain Ratio             -0.016309
# Jarque-Bera Statistic           2.138513
# JB p-value                      0.343264
# Ljung-Box p-value (lag=5)       0.350749
# Alpha                          -0.022657
# Beta                           -0.083209
# Information Ratio              -0.558064
# Tracking Error (%)             29.384612
# Up Capture Ratio (%)           -8.676634
# Down Capture Ratio (%)         -9.584210
# Active Share (%)               20.890742
# c:\Users\Kishan\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Kishan\Desktop\bt\Return_Analyzer\return_analyzer\return_analyzer.py:331: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_returns = self.returns.resample('M').apply(lambda x: (1 + x).prod() - 1)
