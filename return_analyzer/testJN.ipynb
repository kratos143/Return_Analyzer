# %%
import pandas as pd
import numpy as np
import yfinance as yf
import sys
import os
import os

from return_analyzer import ReturnAnalyzer

# %%
import pandas as pd
import numpy as np
import yfinance as yf

# Configuration
benchmark_symbol = "^NSEI"
risk_free_rate = 0.03

# Generate sample portfolio returns
dates = pd.date_range(start="2020-01-01", end="2022-12-31", freq='D')
portfolio_returns = pd.Series(np.random.normal(0.0005, 0.01, len(dates)), index=dates)

# Fetch benchmark data
benchmark_data = yf.download(benchmark_symbol, start="2019-01-01", end="2022-12-31")
benchmark_returns = benchmark_data['Adj Close'].pct_change().dropna()



# Initialize analyzer
analyzer = ReturnAnalyzer(
    returns=portfolio_returns,
    benchmark=benchmark_returns,
    risk_free_rate=risk_free_rate
)

# Generate full report
analyzer.generate_full_report()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Performance Metrics:
#                                    Value
# Total Return (%)               44.503941
# CAGR (%)                       13.078094
# Annual Volatility (%)          15.979772
# Sharpe Ratio                    0.673260
# Sortino Ratio                   0.663595
# Max Drawdown (%)              -26.879581
# Max Drawdown Duration (Days)  535.000000
# Skewness                       -0.150079
# Excess Kurtosis                 0.239857
# Value at Risk (95%) (%)         1.600185
# Conditional VaR (95%) (%)       2.060937
# Win Rate (%)                   53.217158
# Calmar Ratio                    0.486544
# Omega Ratio                     1.112433
# Ulcer Index                     0.136577
# Profit Factor                   1.145433
# Kelly Criterion (%)             6.756846
# Tail Ratio                      1.034981
# Gain to Pain Ratio              0.159419
# Jarque-Bera Statistic           4.588727
# JB p-value                      0.100826
# Ljung-Box p-value (lag=5)       0.372452
# Alpha                           0.104295
# Beta                            0.025221
# Information Ratio              -0.084205
# Tracking Error (%)             27.179433
# Up Capture Ratio (%)            7.850856
# Down Capture Ratio (%)         -3.532430
# Active Share (%)               19.757299
# c:\Users\Kishan\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Kishan\Desktop\bt\Return_Analyzer\return_analyzer\return_analyzer.py:370: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_returns = self.returns.resample('M').apply(lambda x: (1 + x).prod() - 1)
