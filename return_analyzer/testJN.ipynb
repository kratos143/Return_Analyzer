# %%
import pandas as pd
import numpy as np
import yfinance as yf
import sys
import os
from return_analyzer import ReturnAnalyzer

# %%
# Configuration
benchmark_symbol = "^NSEI"
risk_free_rate = 0.03

# Generate sample portfolio returns
dates = pd.date_range(start="2020-01-01", end="2024-12-31", freq='D')
portfolio_returns = pd.Series(np.random.normal(0.0005, 0.01, len(dates)), index=dates)

# Fetch benchmark data
benchmark_data = yf.download(benchmark_symbol, start="2019-01-01", end="2024-12-31")
benchmark_returns = benchmark_data['Adj Close'].pct_change().dropna()



# Initialize analyzer
analyzer = ReturnAnalyzer(
    returns=portfolio_returns,
    benchmark=benchmark_returns,
    risk_free_rate=risk_free_rate
)

# Generate full report
analyzer.generate_full_report()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Performance Metrics:
#                                    Value
# Total Return (%)               82.594071
# CAGR (%)                       12.806248
# Annual Volatility (%)          15.776846
# Sharpe Ratio                    0.669625
# Sortino Ratio                   0.701826
# Max Drawdown (%)              -15.924085
# Max Drawdown Duration (Days)  204.000000
# Skewness                        0.135894
# Excess Kurtosis                 0.046317
# Value at Risk (95%) (%)         1.574321
# Conditional VaR (95%) (%)       1.931859
# Win Rate (%)                   51.294498
# Calmar Ratio                    0.804206
# Omega Ratio                     1.112499
# Ulcer Index                     0.065341
# Profit Factor                   1.146236
# Kelly Criterion (%)             6.544108
# Tail Ratio                      1.110589
# Gain to Pain Ratio              0.182133
# Jarque-Bera Statistic           3.914709
# JB p-value                      0.141232
# Ljung-Box p-value (lag=5)       0.104200
# Alpha                           0.105423
# Beta                            0.001795
# Information Ratio              -0.075721
# Tracking Error (%)             24.758527
# Up Capture Ratio (%)            7.270379
# Down Capture Ratio (%)         -6.494705
# Active Share (%)               18.543501
# c:\Users\Kishan\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Kishan\Desktop\bt\Return_Analyzer\return_analyzer\return_analyzer.py:370: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_returns = self.returns.resample('M').apply(lambda x: (1 + x).prod() - 1)
